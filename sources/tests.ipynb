# %%
from rsc import *

p = RSC("https://raw.githubusercontent.com/nicolasgallandpro/ernestine-data/main/medias_indeps.rsc")
p.fill_rsc()
# Out:
# input https://www.off-investigation.fr/feed/
# input https://www.bastamag.net/spip.php?page=backend
# input https://lagedefaire-lejournal.fr/feed/input https://reporterre.net/spip.php?page=backend-simple
#
# input https://www.youtube.com/channel/UCQgWpmt02UtJkyO32HGUASQ
# input https://www.youtube.com/channel/UCVeMw72tepFl1Zt5fvf9QKQ
# inputinput https://lvsl.fr/feed/
#  input https://la-bas.org/spip.php?page=backend
# https://theconversation.com/fr/articles.atom
# input https://theconversation.com/ca-fr/home-page/articles.atom
# input https://www.acrimed.org/spip.php?page=backend
# input https://www.institut-rousseau.fr/feed/
# input https://www.fakirpresse.info/spip.php?page=backend
# input https://www.heidi.news/articles.rss
# input https://reflets.info/feeds/public
# input https://www.lesnouvellesnews.fr/feed
# input https://lesjours.fr/rss.xml
# input https://rapportsdeforce.fr/feed
# input https://radioparleur.net/feed/
# input https://multinationales.org/spip.php?page=backend
# input https://www.alternatives-economiques.fr/rss.xml
# input https://www.mediapart.fr/articles/feed
# input https://backend.streetpress.com/rss.xml
# inputinput https://api.arretsurimages.net/api/public/rss/all-content
#  inputhttps://api.blast-info.fr/rss.xml
#  https://www.mediacites.fr/feed/
# input https://www.bondyblog.fr/feed/
# input https://www.monde-diplomatique.fr/rss/
# input https://afriquexxi.info/?page=backend&lang=fr
# input https://guitinews.fr/feed/
# input https://www.youtube.com/channel/UC2ijB3_Fg2pIW1g6FeIiYKA
# input https://mrmondialisation.org/feed/
# inputinput https://predictalab.medium.com/feed
#  https://up-magazine.info/feed/
# input https://www.youtube.com/playlist?list=PLIVcDWpMT7KfTCsp2It3EVmMwG2C7CfPf
# input https://feeds.acast.com/public/shows/in-extenso
# input https://www.youtube.com/channel/UCBiAHZy9Gghpt0JyDaz3SYw
# input https://themarkup.org/feeds/rss.xml
# inputinput input  https://feeds.feedburner.com/pudding/feedhttps://poliverse.fr/index.xml
# ERROR:root:https://lagedefaire-lejournal.fr/feed/: ConnectTimeout.
# https://www.youtube.com/channel/UC2ijB3_Fg2pIW1g6FeIiYKA
# https://i.ytimg.com/vi/3n3Hq7XSBjA/maxresdefault.jpg found for https://www.youtube.com/watch?v=3n3Hq7XSBjA
# https://guitinews.fr/wp-content/uploads/2022/04/Les-cinq-actualités-de-la-semaine-1.png found for https://guitinews.fr/a-chaud/les-cinq-actualites-de-la-semaine-8/
# https://lesjours.fr/ressources/opengraph/image/ep12-demba-sy-france-img-header/ep12-demba-sy-france-img-header-1.jpeg found for https://lesjours.fr/obsessions/senegal-canaries/ep12-demba-sy-france/?utm_source=rss-feed&utm_medium=RSS&utm_campaign=rss-feed
# https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/075-musienko-notitle220508-np8ej.jpg found for https://www.mediapart.fr/journal/international/130522/l-avenir-compromis-des-abondantes-matieres-premieres-ukrainiennes
# https://www.monde-diplomatique.fr/local/couv/1980-11-r.jpg found for https://www.monde-diplomatique.fr/1980/11/GEORGE/35855
# https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/20220513-img-violences-la-sortie-de-l-hopital-du-cercueil-de-la-journaliste-palestinienne-1.jpg found for https://www.mediapart.fr/journal/international/130522/violences-la-sortie-de-l-hopital-du-cercueil-de-la-journaliste-palestinienne
# https://i.ytimg.com/vi/7jFRnWmOjd4/hqdefault.jpg found for https://www.youtube.com/watch?v=7jFRnWmOjd4
# https://i.ytimg.com/vi/7jFRnWmOjd4/hqdefault.jpg found for https://www.youtube.com/watch?v=7jFRnWmOjd4
# https://heidi-17455.kxcdn.com/photos/487c1ee9-5ca6-46b0-b172-a53e2a44cec6/medium found for https://www.heidi.news/articles/peut-on-evaluer-le-racisme-avec-des-propos-racistes-et-antisemites
# https://images.theconversation.com/files/462978/original/file-20220513-13-bebhq0.jpg?ixlib=rb-1.1.0&rect=12%2C805%2C4057%2C2025&q=45&auto=format&w=1356&h=668&fit=crop found for https://theconversation.com/on-peut-enfin-voir-le-trou-noir-au-centre-de-notre-galaxie-et-cest-un-exploit-182982
# https://api.arretsurimages.net/api/public/media/20220513/action/show?format=thumbnail&t=2022-05-13T15:58:19+02:00 found for https://www.arretsurimages.net/emissions/arret-sur-images/nupes-cest-pas-le-programme-le-plus-a-gauche-de-lhistoire
# https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/20220513-img-pole-emploi-condamne-pour-harcelement-moral-1.jpg found for https://www.mediapart.fr/journal/economie/130522/pole-emploi-condamne-pour-harcelement-moral
# https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/20220513-img-louise-labe-le-retour-1.jpg found for https://www.mediapart.fr/journal/culture-idees/130522/louise-labe-quel-plaisir
# https://heidi-17455.kxcdn.com/photos/7d967ab8-d13d-4f27-b596-2e0f6ae75191/medium found for https://www.heidi.news/articles/aujourd-hui-le-vetement-le-plus-durable-est-celui-qu-on-n-achete-pas
# https://www.off-investigation.fr/wp-content/uploads/2022/05/Ruffin-Rivoire.jpg found for https://www.off-investigation.fr/lvmh-contre-ruffin-acheter-la-justice/
# https://reporterre.net/local/cache-gd2/6f/feb4a73a1f9d77ba0e5a76e5ccf09b.jpg?1652448481 found for https://reporterre.net/Croissance-travail-et-role-de-l-Etat-un-Bac-d-economie-sous-le-signe-du-neoliberalisme
# https://heidi-17455.kxcdn.com/photos/c9e2aaa5-0f4c-45f4-9fa3-129c24291c80/medium found for https://www.heidi.news/articles/accord-pour-reduire-le-gaspillage-alimentaire-les-consommateurs-sont-les-grands-absents
# https://la-bas.org/local/cache-gd2/62/f678b6b8bde6dec20a1a1a199ca184.jpg?1652366125 found for https://la-bas.org/6740
# https://images.theconversation.com/files/458686/original/file-20220419-22-pjyexx.jpeg?ixlib=rb-1.1.0&rect=14%2C0%2C4662%2C2327&q=45&auto=format&w=1356&h=668&fit=crop found for https://theconversation.com/entendez-vous-les-ecureuils-decouvrez-ce-quils-se-racontent-181220
# https://mrmondialisation.org/wp-content/uploads/2022/05/photo-la-fabrik-a-vrac-charlotte-21-1.jpg found for https://mrmondialisation.org/quand-le-reve-du-vrac-naboutit-pas-le-combat-de-charlotte/
# https://heidi-17455.kxcdn.com/photos/1abe1ed2-8964-4d4e-9629-552c3c1eaf00/medium found for https://www.heidi.news/articles/tonga-l-eruption-de-janvier-etait-la-plus-puissante-jamais-observee-depuis-1883
# https://backend.streetpress.com/sites/default/files/field/image/capture_decran_2022-03-17_a_14.45.32.png?1652478467715 found for https://www.streetpress.com/sujet/1652443695-eleve-vire-ecole-police-base-fausses-accusations-turc-justice
# https://mrkp-static-production.themarkup.org/uploads/2022/05/mark-as-read-final-reduced-1200x628.jpg found for https://themarkup.org/mark-as-read/2022/05/13/apple-privacy-push-euro-bills-and-india-debate
# https://lvsl.fr/wp-content/uploads/2022/05/POUTIN_BIDEN_12052022_1920x1080.png found for https://lvsl.fr/la-guerre-economique-contre-la-russie-est-elle-un-echec/
# https://up-magazine.info/wp-content/uploads/2022/05/urbanite-verte-montreuil.jpg found for https://up-magazine.info/arts-3/102822-urbanite-verte-a-montreuil/
# https://heidi-17455.kxcdn.com/photos/6ceef1b1-09cd-4320-a3bb-94ecf1e0bbea/medium found for https://www.heidi.news/articles/elon-musk-annonce-sur-twitter-qu-il-suspend-le-rachat-de-twitter
# https://heidi-17455.kxcdn.com/photos/4c5f1c89-e4e7-428b-b236-b2146ae65194/medium found for https://www.heidi.news/articles/le-marche-des-cryptomonnaies-se-souviendra-du-mois-de-mai-2022
# https://i.ytimg.com/vi/R2Bif9xwOLs/hqdefault.jpg found for https://www.youtube.com/watch?v=R2Bif9xwOLs
# https://i.ytimg.com/vi/R2Bif9xwOLs/hqdefault.jpg found for https://www.youtube.com/watch?v=R2Bif9xwOLs
# https://static.mediapart.fr/etmagine/og/journal/files/2022/05/12/20220512-img-au-mali-l-ombre-de-wagner-plane-sur-plusieurs-exactions-1.jpg found for https://www.mediapart.fr/journal/international/130522/au-mali-l-ombre-de-wagner-plane-sur-plusieurs-exactions
# https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/000-par6750816.jpg found for https://www.mediapart.fr/journal/international/130522/andre-markowicz-en-ukraine-poutine-veut-punir-la-democratie
# https://static.mediapart.fr/etmagine/og/journal/files/2022/05/12/port-de-shanghai.jpg found for https://www.mediapart.fr/journal/international/130522/le-grand-dereglement-de-la-machine-mondiale-de-production
# https://basta.media/local/cache-gd2/cb/1689b24ef5a1dfee45d3a29ed2c8d8.jpg?1652193222 found for https://basta.media/quand-la-caf-porte-plainte-contre-un-allocataire-de-l-aah-coince-a-l-etranger
# https://basta.media/local/cache-gd2/44/82a09f71184d6a9d798f44e121e8b1.jpg?1652097506 found for https://basta.media/RSA-allocations-des-benevoles-se-mobilisent-pour-debloquer-les-dossiers-des-naufrages-de-la-caf-Alsace
# https://www.alternatives-economiques.fr/sites/default/files/public/styles/for_social_networks/public/field/image/agir_423_web.jpg?itok=pEQBliO9 found for https://www.alternatives-economiques.fr/enfin-medicaments-contre-maladies-negligees/00103160
# https://www.alternatives-economiques.fr/sites/default/files/public/styles/large/public/benedicte_manier.png?itok=zKe1QS04 found for https://www.alternatives-economiques.fr/benedicte-manier/soutenir-circuits-courts-meme-apres-covid/00103304
# https://reporterre.net/local/cache-gd2/d7/293fc0db0345423cd3bc152f973c0b.jpg?1652427736 found for https://reporterre.net/Chasser-ou-preserver-La-bataille-autour-du-blaireau
# https://rapportsdeforce.fr/wp-content/uploads/2022/05/existrans900.png found for https://rapportsdeforce.fr/ici-et-maintenant/existransinter-quelles-luttes-pour-les-personnes-trans-et-intersexes-051313708
# https://heidi-17455.kxcdn.com/photos/e75a0474-8cfd-41c3-be50-5bf87419b993/medium found for https://www.heidi.news/articles/les-projets-des-petroliers-vont-faire-exploser-les-emissions-de-co2
# https://reporterre.net/local/cache-gd2/7e/4ed5ce1c2e3ed91cdb48061d2b9840.jpg?1652362004 found for https://reporterre.net/Planification-ecologique-l-imposture-Macron
# https://reporterre.net/local/cache-gd2/25/869fe550a5c904f54bf8e303287f06.jpg?1652425761 found for https://reporterre.net/Les-secheresses-se-propagent-avec-le-vent
# https://heidi-17455.kxcdn.com/photos/6d9ce592-1e82-496b-bb29-60626eacdd78/medium found for https://www.heidi.news/articles/vous-avez-dit-data-literacy
# https://heidi-17455.kxcdn.com/photos/03a3b3ca-777c-4a88-a18a-93865774f00b/medium found for https://www.heidi.news/articles/le-jour-ou-j-ai-penetre-le-bastion-de-netflix-a-paris
# https://api.arretsurimages.net/api/public/media/2022-05-12-pauline2/action/show?format=thumbnail&t=2022-05-12T15:34:09+02:00 found for https://www.arretsurimages.net/articles/nupes-radiographie-dune-panique-editoriale
# https://www.mediacites.fr/wp-content/uploads/2022/05/2022-05-notes-frais-elus-lille-calais-valenciennes.jpg found for https://www.mediacites.fr/enquete/lille/2022/05/13/frais-des-elus-les-premiers-resultats-de-notre-operation-transparence/
#  found for https://afriquexxi.info/article4977.html
# https://heidi-17455.kxcdn.com/photos/30a625fa-4c19-4f99-8492-e11b62a3cf6f/medium found for https://www.heidi.news/articles/la-suisse-atteint-son-jour-du-depassement-un-peu-plus-tard-qu-en-2021
# https://www.alternatives-economiques.fr/sites/default/files/public/styles/for_social_networks/public/field/image/allemagne-industrie-france.jpg?itok=Tqt8G6sY found for https://www.alternatives-economiques.fr/lallemagne-partie-responsable-de-desindustrialisation-francaise/00103322
# https://www.alternatives-economiques.fr/sites/default/files/public/styles/for_social_networks/public/field/image/fed-powell.jpg?itok=jgKfa5AG found for https://www.alternatives-economiques.fr/inflation-banque-centrale-americaine-a-t-failli/00103337

# %%
from pprint import pprint

pprint(p.to_json())
# Out:
# {'categories': [{'entries': [{'author': 'Tom Nicholas',
#                               'id': 'yt:video:3n3Hq7XSBjA',
#                               'image': 'https://i.ytimg.com/vi/3n3Hq7XSBjA/maxresdefault.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 18, 0, 11, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': '2022-05-13T18:00:11+00:00',
#                               'source': 'Tom Nicholas',
#                               'summary': 'Get a full year of Nebula & '
#                                          'Curiosity Stream for just $14.79 '
#                                          'here: '
#                                          'https://curiositystream.com/tomnicholas\n'
#                                          'A video about how billionaire-funded '
#                                          'right-wing “think tanks” such as the '
#                                          'Heritage Foundation, Adam Smith '
#                                          'Institute, Manhattan Institute and '
#                                          'Institute of Economic Affairs '
#                                          'manipulate the news to[...]',
#                               'title': 'Think Tanks: How Fake Experts Shape '
#                                        'the News',
#                               'url': 'https://www.youtube.com/watch?v=3n3Hq7XSBjA'},
#                              {'author': 'Justine Segui',
#                               'id': 'https://guitinews.fr/?p=1358138',
#                               'image': 'https://guitinews.fr/wp-content/uploads/2022/04/Les-cinq-actualités-de-la-semaine-1.png',
#                               'published': datetime.datetime(2022, 5, 13, 17, 40, 40, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 17:40:40 +0000',
#                               'source': 'guiti news',
#                               'summary': 'Du Québec à Mayotte, en passant par '
#                                          'Grande-Synthe, retour sur '
#                                          'l’actualité migratoire de la '
#                                          'semaine.',
#                               'title': 'Les cinq actualités de la semaine',
#                               'url': 'https://guitinews.fr/a-chaud/les-cinq-actualites-de-la-semaine-8/'},
#                              {'author': None,
#                               'id': 'https://lesjours.fr/obsessions/senegal-canaries/ep12-demba-sy-france/',
#                               'image': 'https://lesjours.fr/ressources/opengraph/image/ep12-demba-sy-france-img-header/ep12-demba-sy-france-img-header-1.jpeg',
#                               'published': datetime.datetime(2022, 5, 13, 16, 59, tzinfo=tzutc()),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 16:59:00 GMT',
#                               'source': 'les jours',
#                               'summary': 'Au Sénégal, le désir d’Europe n’est '
#                                          'pas récent. Demba Sy est parti en '
#                                          '1968, a fait sa vie en France et est '
#                                          'rentré quarante ans plus tard.',
#                               'title': '« Tous ceux qui en ont l’occasion s’en '
#                                        'vont »',
#                               'url': 'https://lesjours.fr/obsessions/senegal-canaries/ep12-demba-sy-france/?utm_source=rss-feed&utm_medium=RSS&utm_campaign=rss-feed'},
#                              {'author': 'Amélie Poinssot',
#                               'id': '1030589 at https://www.mediapart.fr/',
#                               'image': 'https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/075-musienko-notitle220508-np8ej.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 18, 26, 32, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 18:26:32 +0200',
#                               'source': 'mediapart',
#                               'summary': 'L’Ukraine regorge de ressources '
#                                          'agricoles, minières et gazières. '
#                                          'Entre impossibilité de semer, '
#                                          'pillages et blocus de la mer Noire, '
#                                          'la guerre menée par l’armée russe '
#                                          'met à mal l’exploitation des '
#                                          'matières premières ukrainiennes et '
#                                          'empêche leur exportation.',
#                               'title': 'L’avenir compromis des abondantes '
#                                        'matières premières ukrainiennes',
#                               'url': 'https://www.mediapart.fr/journal/international/130522/l-avenir-compromis-des-abondantes-matieres-premieres-ukrainiennes'},
#                              {'author': 'Susan George',
#                               'id': None,
#                               'image': 'https://www.monde-diplomatique.fr/local/couv/1980-11-r.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 16, 16, 10, tzinfo=tzlocal()),
#                               'published_key': 'updated',
#                               's_published': '2022-05-13T16:16:10Z',
#                               'source': 'le monde diplo',
#                               'summary': 'Quand, en 1948, Ceylan obtint de la '
#                                          'Grande-Bretagne son indépendance '
#                                          'avec statut de dominion (la '
#                                          'République de Sri-Lanka ne fut '
#                                          "proclamée qu'en 1972), ce pays était "
#                                          'sans doute le plus développé de '
#                                          "l'Asie, après le Japon. Des "
#                                          'trente-sept nations que la Banque '
#                                          'mondiale classe dans la catégorie '
#                                          'des pay[...]',
#                               'title': 'Les progrès du libéralisme économique '
#                                        'à Sri-Lanka',
#                               'url': 'https://www.monde-diplomatique.fr/1980/11/GEORGE/35855'},
#                              {'author': 'Alice Froussard, Agence France-Presse',
#                               'id': '1030616 at https://www.mediapart.fr/',
#                               'image': 'https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/20220513-img-violences-la-sortie-de-l-hopital-du-cercueil-de-la-journaliste-palestinienne-1.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 18, 9, 47, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 18:09:47 +0200',
#                               'source': 'mediapart',
#                               'summary': 'Des violences ont éclaté vendredi 13 '
#                                          'mai dans l’enceinte d’un hôpital à '
#                                          'Jérusalem à la sortie du cercueil de '
#                                          'la journaliste palestinienne Shireen '
#                                          'Abu Akleh, où la police israélienne '
#                                          'a dispersé une foule brandissant des '
#                                          'drapeaux palestiniens, selon des '
#                                          'journalistes de l’AFP sur place et '
#                                          'des médias lo[...]',
#                               'title': 'Violences à la sortie de l’hôpital du '
#                                        'cercueil de la journaliste '
#                                        'palestinienne',
#                               'url': 'https://www.mediapart.fr/journal/international/130522/violences-la-sortie-de-l-hopital-du-cercueil-de-la-journaliste-palestinienne'},
#                              {'author': 'Backseat',
#                               'id': 'yt:video:7jFRnWmOjd4',
#                               'image': 'https://i.ytimg.com/vi/7jFRnWmOjd4/hqdefault.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 16, 0, 3, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': '2022-05-13T16:00:03+00:00',
#                               'source': 'backseat',
#                               'summary': '📢 Soutiens Backseat sur uTip ! '
#                                          'https://utip.io/jeanmassiet\n'
#                                          '🔥 N’hésite pas à t’abonner et à '
#                                          'lâcher un pouce bleu et un '
#                                          'commentaire pour soutenir la chaîne '
#                                          '! 👍\n'
#                                          'Pour cette trente-troisième édition '
#                                          'de Backeat, Jean, Usul, Léa et Sasha '
#                                          'reçoivent Pépipin pour discuter de '
#                                          "l'actualité et de sa relation à "
#                                          'la[...]',
#                               'title': "PÉPIPIN : L'INVITÉE DE LA SEMAINE - "
#                                        'Backseat #33',
#                               'url': 'https://www.youtube.com/watch?v=7jFRnWmOjd4'},
#                              {'author': 'Backseat',
#                               'id': 'yt:video:7jFRnWmOjd4',
#                               'image': 'https://i.ytimg.com/vi/7jFRnWmOjd4/hqdefault.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 16, 0, 3, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': '2022-05-13T16:00:03+00:00',
#                               'source': 'Backseat',
#                               'summary': '📢 Soutiens Backseat sur uTip ! '
#                                          'https://utip.io/jeanmassiet\n'
#                                          '🔥 N’hésite pas à t’abonner et à '
#                                          'lâcher un pouce bleu et un '
#                                          'commentaire pour soutenir la chaîne '
#                                          '! 👍\n'
#                                          'Pour cette trente-troisième édition '
#                                          'de Backeat, Jean, Usul, Léa et Sasha '
#                                          'reçoivent Pépipin pour discuter de '
#                                          "l'actualité et de sa relation à "
#                                          'la[...]',
#                               'title': "PÉPIPIN : L'INVITÉE DE LA SEMAINE - "
#                                        'Backseat #33',
#                               'url': 'https://www.youtube.com/watch?v=7jFRnWmOjd4'},
#                              {'author': 'Annick Chevillot',
#                               'id': 'https://www.heidi.news/articles/peut-on-evaluer-le-racisme-avec-des-propos-racistes-et-antisemites',
#                               'image': 'https://heidi-17455.kxcdn.com/photos/487c1ee9-5ca6-46b0-b172-a53e2a44cec6/medium',
#                               'published': datetime.datetime(2022, 5, 13, 18, 0, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 18:00:00 +0200',
#                               'source': 'heidi news',
#                               'summary': 'C’est une enquête d’opinion comme '
#                                          'l’Office fédéral de la statistique '
#                                          '(OFS) en fait beaucoup. Depuis le '
#                                          'début de l’année, un panel de '
#                                          'personnes vivant en Suisse est '
#                                          'invité à répondre à un sondage sur '
#                                          'le vivre ensemble en Suisse. Il y '
#                                          'est question des étrangers en '
#                                          'général, des musulmans, des noirs, '
#                                          'de[...]',
#                               'title': 'Peut-on évaluer le racisme avec des '
#                                        'propos racistes et antisémites?',
#                               'url': 'https://www.heidi.news/articles/peut-on-evaluer-le-racisme-avec-des-propos-racistes-et-antisemites'},
#                              {'author': 'Sylvain Chaty, Professeur des '
#                                         'Universités, astrophysicien au CEA, '
#                                         'Université Paris Cité',
#                               'id': 'tag:theconversation.com,2011:article/182982',
#                               'image': 'https://images.theconversation.com/files/462978/original/file-20220513-13-bebhq0.jpg?ixlib=rb-1.1.0&rect=12%2C805%2C4057%2C2025&q=45&auto=format&w=1356&h=668&fit=crop',
#                               'published': datetime.datetime(2022, 5, 13, 15, 59, 43, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': '2022-05-13T15:59:43Z',
#                               'source': 'the conversation fr',
#                               'summary': 'La première image de Sgr A*, le trou '
#                                          'noir supermassif situé au centre de '
#                                          'notre galaxie. eso2208-eht-mwa, CC '
#                                          'BY-SAAu centre de notre galaxie, la '
#                                          'Voie lactée, trône un trou noir '
#                                          'supermassif, autour duquel nous '
#                                          'tournons. Jusqu’à présent, personne '
#                                          'n’avait réussi à l’observer, et pour '
#                                          'cause, un trou noir[...]',
#                               'title': 'On peut enfin voir le trou noir au '
#                                        'centre de notre galaxie et c’est un '
#                                        'exploit',
#                               'url': 'https://theconversation.com/on-peut-enfin-voir-le-trou-noir-au-centre-de-notre-galaxie-et-cest-un-exploit-182982'},
#                              {'author': None,
#                               'id': 'https://www.arretsurimages.net/emissions/arret-sur-images/nupes-cest-pas-le-programme-le-plus-a-gauche-de-lhistoire',
#                               'image': 'https://api.arretsurimages.net/api/public/media/20220513/action/show?format=thumbnail&t=2022-05-13T15:58:19+02:00',
#                               'published': datetime.datetime(2022, 5, 13, 17, 47, 38, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 17:47:38 +0200',
#                               'source': 'arrêt sur image',
#                               'summary': '',
#                               'title': 'Nupes : "C\'est pas le programme le '
#                                        'plus à gauche de l\'Histoire"',
#                               'url': 'https://www.arretsurimages.net/emissions/arret-sur-images/nupes-cest-pas-le-programme-le-plus-a-gauche-de-lhistoire'},
#                              {'author': 'Cécile Hautefeuille',
#                               'id': '1030601 at https://www.mediapart.fr/',
#                               'image': 'https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/20220513-img-pole-emploi-condamne-pour-harcelement-moral-1.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 17, 20, 52, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 17:20:52 +0200',
#                               'source': 'mediapart',
#                               'summary': 'Pôle emploi a été condamné pour '
#                                          '«harcèlement moral» et «violation de '
#                                          'son obligation de sécurité» envers '
#                                          'un salarié de la direction des '
#                                          'affaires internationales. Le '
#                                          'management de l’ancienne directrice '
#                                          'du service était décrié depuis des '
#                                          'années.',
#                               'title': 'Pôle emploi condamné pour «harcèlement '
#                                        'moral»',
#                               'url': 'https://www.mediapart.fr/journal/economie/130522/pole-emploi-condamne-pour-harcelement-moral'},
#                              {'author': 'Lise Wajeman',
#                               'id': '1030554 at https://www.mediapart.fr/',
#                               'image': 'https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/20220513-img-louise-labe-le-retour-1.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 17, 19, 38, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 17:19:38 +0200',
#                               'source': 'mediapart',
#                               'summary': 'Depuis quelques années, Louise Labé '
#                                          'fait l’objet d’une polémique: elle '
#                                          'ne serait pas l’autrice de ses '
#                                          'écrits, attribuables à un petit '
#                                          'cercle d’hommes. Une nouvelle '
#                                          'édition des «Œuvres» s’attache à '
#                                          'rendre à la poète de la Renaissance '
#                                          'la maternité de ses textes, en '
#                                          'plaçant la question du genre au '
#                                          'cent[...]',
#                               'title': 'Louise Labé, quel plaisir',
#                               'url': 'https://www.mediapart.fr/journal/culture-idees/130522/louise-labe-quel-plaisir'},
#                              {'author': 'Lisa Baconnière',
#                               'id': 'https://www.heidi.news/articles/aujourd-hui-le-vetement-le-plus-durable-est-celui-qu-on-n-achete-pas',
#                               'image': 'https://heidi-17455.kxcdn.com/photos/7d967ab8-d13d-4f27-b596-2e0f6ae75191/medium',
#                               'published': datetime.datetime(2022, 5, 13, 17, 17, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 17:17:00 +0200',
#                               'source': 'heidi news',
#                               'summary': 'Le dernier rapport du Giec appelle à '
#                                          'plus de sobriété dans notre demande '
#                                          'en ressources et en énergie. Cela '
#                                          'passe aussi, à l’échelle des '
#                                          'consommateurs, par la demande '
#                                          'vestimentaire. Fabriquer des '
#                                          'vêtements nécessite notamment '
#                                          'beaucoup d’eau. Et génère des '
#                                          'problèmes en amont et en aval de la '
#                                          'chaîne.\n'
#                                          'L[...]',
#                               'title': '«Aujourd’hui, le vêtement le plus '
#                                        "durable est celui qu’on n'achète pas»",
#                               'url': 'https://www.heidi.news/articles/aujourd-hui-le-vetement-le-plus-durable-est-celui-qu-on-n-achete-pas'},
#                              {'author': 'djibee',
#                               'id': 'https://www.off-investigation.fr/?p=2998',
#                               'image': 'https://www.off-investigation.fr/wp-content/uploads/2022/05/Ruffin-Rivoire.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 14, 48, 45, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 14:48:45 +0000',
#                               'source': 'off investigation',
#                               'summary': 'LVMH contre Ruffin : acheter la '
#                                          'justice ?Manale Makhchoun\xa0|\xa0'
#                                          'Jean-Baptiste Rivoire François '
#                                          'Ruffin et ses proches à la Cour '
#                                          'd’appel de Paris le 9 ...',
#                               'title': 'LVMH contre Ruffin : acheter la '
#                                        'justice ?',
#                               'url': 'https://www.off-investigation.fr/lvmh-contre-ruffin-acheter-la-justice/'},
#                              {'author': None,
#                               'id': 'https://reporterre.net/Croissance-travail-et-role-de-l-Etat-un-Bac-d-economie-sous-le-signe-du-neoliberalisme',
#                               'image': 'https://reporterre.net/local/cache-gd2/6f/feb4a73a1f9d77ba0e5a76e5ccf09b.jpg?1652448481',
#                               'published': datetime.datetime(2022, 5, 13, 14, 2, 32, tzinfo=tzlocal()),
#                               'published_key': 'updated',
#                               's_published': '2022-05-13T14:02:32Z',
#                               'source': 'reporterre',
#                               'summary': "À l'épreuve de spécialité Sciences "
#                                          'économiques et sociales du '
#                                          'baccalauréat 2022, plusieurs '
#                                          'questions semblaient inviter les '
#                                          "élèves à faire l'apologie du "
#                                          'néolibéralisme. La faute aux '
#                                          "réformes de l'Éducation nationale, "
#                                          'selon la coprésidente de '
#                                          "l'Association des professeurs de "
#                                          'sciences économiques et s[...]',
#                               'title': 'Croissance, travail et rôle de '
#                                        "l'État\xa0: un Bac d'économie sous le "
#                                        'signe du néolibéralisme',
#                               'url': 'https://reporterre.net/Croissance-travail-et-role-de-l-Etat-un-Bac-d-economie-sous-le-signe-du-neoliberalisme'},
#                              {'author': 'Nina Schretr',
#                               'id': 'https://www.heidi.news/articles/accord-pour-reduire-le-gaspillage-alimentaire-les-consommateurs-sont-les-grands-absents',
#                               'image': 'https://heidi-17455.kxcdn.com/photos/c9e2aaa5-0f4c-45f4-9fa3-129c24291c80/medium',
#                               'published': datetime.datetime(2022, 5, 13, 15, 59, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 15:59:00 +0200',
#                               'source': 'heidi news',
#                               'summary': 'Le 12 mai, 28 entreprises et '
#                                          'fédérations se sont engagées dans un '
#                                          'accord avec la Confédération à '
#                                          'réduire les pertes alimentaires '
#                                          'évitables de moitié d’ici à 2030, '
#                                          'avec un premier pallier à 25% en '
#                                          '2025. Un accord inédit et salué, '
#                                          'mais dont les organisations de '
#                                          'consommateurs sont totalement '
#                                          'absentes, [...]',
#                               'title': 'Accord contre le gaspillage '
#                                        'alimentaire: les consommateurs sont '
#                                        'les grands absents',
#                               'url': 'https://www.heidi.news/articles/accord-pour-reduire-le-gaspillage-alimentaire-les-consommateurs-sont-les-grands-absents'},
#                              {'author': None,
#                               'id': 'https://la-bas.org/6740',
#                               'image': 'https://la-bas.org/local/cache-gd2/62/f678b6b8bde6dec20a1a1a199ca184.jpg?1652366125',
#                               'published': datetime.datetime(2022, 5, 13, 13, 56, 24, tzinfo=tzlocal()),
#                               'published_key': 'updated',
#                               's_published': '2022-05-13T13:56:24Z',
#                               'source': 'là bas',
#                               'summary': 'Amie abonnée, ami abonné,\n'
#                                          "Vous êtes abonné à Là-bas si j'y "
#                                          "suis, et c'est très bien. Mais "
#                                          'êtes-vous abonné à la chaîne YouTube '
#                                          "d'Emmanuel Macron ? Non ? Et bien "
#                                          'dans ce cas vous avez raté le '
#                                          "chef-d'œuvre de la propagande "
#                                          'présidentielle, intitulé « Cinq ans '
#                                          '», soit deux épisodes de 40 minutes '
#                                          'chacun [...]',
#                               'title': 'Macron II, roi de la propagande',
#                               'url': 'https://la-bas.org/6740'},
#                              {'author': 'Shannon M. Digweed, Associate '
#                                         'professor, Psychology and Biological '
#                                         'Sciences, MacEwan University',
#                               'id': 'tag:theconversation.com,2011:article/181220',
#                               'image': 'https://images.theconversation.com/files/458686/original/file-20220419-22-pjyexx.jpeg?ixlib=rb-1.1.0&rect=14%2C0%2C4662%2C2327&q=45&auto=format&w=1356&h=668&fit=crop',
#                               'published': datetime.datetime(2022, 5, 13, 13, 29, 54, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': '2022-05-13T13:29:54Z',
#                               'source': 'the conversation ca-fr',
#                               'summary': 'Les cris de crécelle des écureuils '
#                                          'peuvent être une façon d’annoncer '
#                                          'leur présence. (Shutterstock)Je suis '
#                                          'une scientifique spécialiste du '
#                                          'comportement des écureuils, et la '
#                                          'question que l’on me pose le plus '
#                                          'souvent est\xa0: «\xa0Comment les '
#                                          'chasser de ma cour\xa0?\xa0»\n'
#                                          'La vie d’un écureuil n’est pas aussi '
#                                          'facile[...]',
#                               'title': 'Entendez-vous les écureuils ? '
#                                        "Découvrez ce qu'ils se racontent",
#                               'url': 'https://theconversation.com/entendez-vous-les-ecureuils-decouvrez-ce-quils-se-racontent-181220'},
#                              {'author': 'Sharon Houri',
#                               'id': 'https://mrmondialisation.org/?p=546015',
#                               'image': 'https://mrmondialisation.org/wp-content/uploads/2022/05/photo-la-fabrik-a-vrac-charlotte-21-1.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 12, 58, 38, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 12:58:38 +0000',
#                               'source': 'mr mondialisation',
#                               'summary': 'En 2019, Charlotte et Aurélie, '
#                                          'soucieuses de l’environnement, '
#                                          'créent la Fabrik’ A Vrac : une '
#                                          'épicerie de produits consignés et '
#                                          'disponibles en drive. Installées en '
#                                          'région nantaise, elles espéraient '
#                                          'faciliter à la population locale une '
#                                          'consommation de proximité, en '
#                                          'circuit-court et libérée du '
#                                          'tout-pla[...]',
#                               'title': 'Quand le rêve du vrac n’aboutit pas : '
#                                        'le combat de Charlotte',
#                               'url': 'https://mrmondialisation.org/quand-le-reve-du-vrac-naboutit-pas-le-combat-de-charlotte/'},
#                              {'author': 'Sarah Sermondadaz',
#                               'id': 'https://www.heidi.news/articles/tonga-l-eruption-de-janvier-etait-la-plus-puissante-jamais-observee-depuis-1883',
#                               'image': 'https://heidi-17455.kxcdn.com/photos/1abe1ed2-8964-4d4e-9629-552c3c1eaf00/medium',
#                               'published': datetime.datetime(2022, 5, 13, 14, 30, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 14:30:00 +0200',
#                               'source': 'heidi news',
#                               'summary': 'Le 15 janvier 2022, le volcan Hunga, '
#                                          'dans l’archipel volcanique des îles '
#                                          'Tonga, se réveillait d’un sommeil de '
#                                          'plus de 10 ans. Son éruption '
#                                          'explosive, aggravée par la proximité '
#                                          'du magma avec le niveau de la mer, a '
#                                          'été d’une violence inédite: elle a '
#                                          'déclenché un tsunami qui a presque '
#                                          'entièrement subme[...]',
#                               'title': "Tonga: l'éruption de janvier était la "
#                                        'plus puissante jamais observée depuis '
#                                        '1883',
#                               'url': 'https://www.heidi.news/articles/tonga-l-eruption-de-janvier-etait-la-plus-puissante-jamais-observee-depuis-1883'},
#                              {'author': 'fanta-kébé',
#                               'id': '15027 at https://backend.streetpress.com',
#                               'image': 'https://backend.streetpress.com/sites/default/files/field/image/capture_decran_2022-03-17_a_14.45.32.png?1652478467715',
#                               'published': datetime.datetime(2022, 5, 13, 12, 8, 15, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 12:08:15 +0000',
#                               'source': 'street press',
#                               'summary': 'Ogur, élève en école de police, est '
#                                          'accusé d’avoir menacé l’un de ses '
#                                          'formateurs. Le parquet va classer '
#                                          'l’affaire mais son école va tout de '
#                                          'même décider de le virer.Enquête',
#                               'title': 'Un élève viré de l’école de police sur '
#                                        'la base de fausses accusations',
#                               'url': 'https://www.streetpress.com/sujet/1652443695-eleve-vire-ecole-police-base-fausses-accusations-turc-justice'},
#                              {'author': 'Jeremy Wagstaff',
#                               'id': 'tag:themarkup.org,2019,43398',
#                               'image': 'https://mrkp-static-production.themarkup.org/uploads/2022/05/mark-as-read-final-reduced-1200x628.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 8, 0, tzinfo=tzoffset(None, -14400)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 08:00:00 -0400',
#                               'source': 'The Markup',
#                               'summary': 'Tech and privacy perspectives from '
#                                          'around the globe',
#                               'title': 'Apple Privacy Push, Euro Bills, and '
#                                        'India Debate',
#                               'url': 'https://themarkup.org/mark-as-read/2022/05/13/apple-privacy-push-euro-bills-and-india-debate'},
#                              {'author': 'Frédéric Lemaire',
#                               'id': 'https://lvsl.fr/?p=59987',
#                               'image': 'https://lvsl.fr/wp-content/uploads/2022/05/POUTIN_BIDEN_12052022_1920x1080.png',
#                               'published': datetime.datetime(2022, 5, 13, 11, 57, 24, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 11:57:24 +0000',
#                               'source': 'le vent se lève',
#                               'summary': 'Fin février 2022, le G7 adoptait de '
#                                          'lourdes sanctions contre la Russie. '
#                                          'Bruno Le Maire annonçait même une '
#                                          '«\xa0guerre économique et financière '
#                                          'totale\xa0» contre cette dernière – '
#                                          'avant de revenir sur ses propos. '
#                                          'Plus de deux mois plus tard, le '
#                                          'bilan des mesures engagées semble '
#                                          'pour le moins mitigé. Les sa[...]',
#                               'title': 'La «\xa0guerre économique\xa0» contre '
#                                        'la Russie est-elle un échec\xa0?',
#                               'url': 'https://lvsl.fr/la-guerre-economique-contre-la-russie-est-elle-un-echec/'},
#                              {'author': "Rédaction Culture UP' Magazine",
#                               'id': 'https://up-magazine.info/?p=102822',
#                               'image': 'https://up-magazine.info/wp-content/uploads/2022/05/urbanite-verte-montreuil.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 11, 32, 37, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 11:32:37 +0000',
#                               'source': 'up magazine',
#                               'summary': 'Urbanité verte réunit des projets '
#                                          'artistiques et citoyens autour des '
#                                          'questions de nature en ville. '
#                                          'L’exposition propose une immersion '
#                                          'sensible et réflexive depuis une '
#                                          'ville fictionnelle sans nature vers '
#                                          'une cité que les êtres vivants, '
#                                          'végétal, animal et humain, habitent '
#                                          'ensemble et réinventent. Une [...]',
#                               'title': 'Urbanité verte à Montreuil',
#                               'url': 'https://up-magazine.info/arts-3/102822-urbanite-verte-a-montreuil/'},
#                              {'author': 'Grégoire Barbey',
#                               'id': 'https://www.heidi.news/articles/elon-musk-annonce-sur-twitter-qu-il-suspend-le-rachat-de-twitter',
#                               'image': 'https://heidi-17455.kxcdn.com/photos/6ceef1b1-09cd-4320-a3bb-94ecf1e0bbea/medium',
#                               'published': datetime.datetime(2022, 5, 13, 12, 49, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 12:49:00 +0200',
#                               'source': 'heidi news',
#                               'summary': 'C’est par un tweet que le patron de '
#                                          'Tesla annonce la suspension '
#                                          'temporaire… du rachat de Twitter. '
#                                          'Elon Musk a décidément le sens du '
#                                          'spectacle. Le milliardaire attend '
#                                          'des précisions de la part du réseau '
#                                          'social quant au nombre effectif de '
#                                          'faux comptes actifs sur la '
#                                          'plateforme. Il s’appuie en cela sur '
#                                          '[...]',
#                               'title': "Elon Musk annonce sur Twitter qu'il "
#                                        'suspend le rachat... de Twitter',
#                               'url': 'https://www.heidi.news/articles/elon-musk-annonce-sur-twitter-qu-il-suspend-le-rachat-de-twitter'},
#                              {'author': 'Grégoire Barbey',
#                               'id': 'https://www.heidi.news/articles/le-marche-des-cryptomonnaies-se-souviendra-du-mois-de-mai-2022',
#                               'image': 'https://heidi-17455.kxcdn.com/photos/4c5f1c89-e4e7-428b-b236-b2146ae65194/medium',
#                               'published': datetime.datetime(2022, 5, 13, 12, 30, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 12:30:00 +0200',
#                               'source': 'heidi news',
#                               'summary': 'Une cryptomonnaie dite stable '
#                                          '(stablecoin) est en état de mort '
#                                          'clinique. Le TerraUSD, dont la '
#                                          'valeur est censée être adossée au '
#                                          'dollar américain, a perdu son '
#                                          'ancrage sur cette devise '
#                                          'traditionnelle de référence depuis '
#                                          'lundi 9 mai. Et tout porte à croire '
#                                          'que cet important stablecoin, le '
#                                          'troisième en [...]',
#                               'title': 'Le marché des cryptomonnaies se '
#                                        'souviendra du mois de mai 2022',
#                               'url': 'https://www.heidi.news/articles/le-marche-des-cryptomonnaies-se-souviendra-du-mois-de-mai-2022'},
#                              {'author': 'Backseat',
#                               'id': 'yt:video:R2Bif9xwOLs',
#                               'image': 'https://i.ytimg.com/vi/R2Bif9xwOLs/hqdefault.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 10, 0, 14, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': '2022-05-13T10:00:14+00:00',
#                               'source': 'backseat',
#                               'summary': '📢 Soutiens Backseat sur uTip ! '
#                                          'https://utip.io/jeanmassiet\n'
#                                          '🔥 N’hésite pas à t’abonner et à '
#                                          'lâcher un pouce bleu et un '
#                                          'commentaire pour soutenir la chaîne '
#                                          '! 👍\n'
#                                          'Pour cette trente-troisième édition '
#                                          'de Backseat, Jean, Usul, Léa, et '
#                                          'Sasha discutent des sujets d’actu de '
#                                          'la semaine : la naissance de la '
#                                          'NUPE[...]',
#                               'title': 'LA SURPRISE NUPES & MACRONIE 2.0 - '
#                                        'Backseat #33',
#                               'url': 'https://www.youtube.com/watch?v=R2Bif9xwOLs'},
#                              {'author': 'Backseat',
#                               'id': 'yt:video:R2Bif9xwOLs',
#                               'image': 'https://i.ytimg.com/vi/R2Bif9xwOLs/hqdefault.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 10, 0, 14, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': '2022-05-13T10:00:14+00:00',
#                               'source': 'Backseat',
#                               'summary': '📢 Soutiens Backseat sur uTip ! '
#                                          'https://utip.io/jeanmassiet\n'
#                                          '🔥 N’hésite pas à t’abonner et à '
#                                          'lâcher un pouce bleu et un '
#                                          'commentaire pour soutenir la chaîne '
#                                          '! 👍\n'
#                                          'Pour cette trente-troisième édition '
#                                          'de Backseat, Jean, Usul, Léa, et '
#                                          'Sasha discutent des sujets d’actu de '
#                                          'la semaine : la naissance de la '
#                                          'NUPE[...]',
#                               'title': 'LA SURPRISE NUPES & MACRONIE 2.0 - '
#                                        'Backseat #33',
#                               'url': 'https://www.youtube.com/watch?v=R2Bif9xwOLs'},
#                              {'author': 'Paul Lorgerie',
#                               'id': '1030354 at https://www.mediapart.fr/',
#                               'image': 'https://static.mediapart.fr/etmagine/og/journal/files/2022/05/12/20220512-img-au-mali-l-ombre-de-wagner-plane-sur-plusieurs-exactions-1.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 11, 26, 25, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 11:26:25 +0200',
#                               'source': 'mediapart',
#                               'summary': 'Des récits de témoins directs, des '
#                                          'documents fournis par des élus '
#                                          'locaux ainsi que des photos '
#                                          'apportent de nouvelles preuves de '
#                                          'l’implication d’«instructeurs '
#                                          'blancs» dans des exactions au Mali. '
#                                          'Selon plusieurs sources, les '
#                                          'éléments de la société privée russe '
#                                          'Wagner opèrent dans le pays depuis '
#                                          'le déb[...]',
#                               'title': 'Au Mali, l’ombre de Wagner plane sur '
#                                        'plusieurs exactions',
#                               'url': 'https://www.mediapart.fr/journal/international/130522/au-mali-l-ombre-de-wagner-plane-sur-plusieurs-exactions'},
#                              {'author': 'François Bougon',
#                               'id': '1030494 at https://www.mediapart.fr/',
#                               'image': 'https://static.mediapart.fr/etmagine/og/journal/files/2022/05/13/000-par6750816.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 11, 25, 45, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 11:25:45 +0200',
#                               'source': 'mediapart',
#                               'summary': 'Pendant plus d’une heure jeudi soir, '
#                                          'au festival L’Histoire à venir, à '
#                                          'Toulouse, le grand traducteur de la '
#                                          'littérature russe André Markowicz a '
#                                          'évoqué le conflit en Ukraine, '
#                                          'Vladimir Poutine, la Russie '
#                                          'd’aujourd’hui et d’hier. Magistral '
#                                          'et saisissant.',
#                               'title': 'André Markowicz:\xa0en Ukraine, '
#                                        'Poutine veut punir la démocratie',
#                               'url': 'https://www.mediapart.fr/journal/international/130522/andre-markowicz-en-ukraine-poutine-veut-punir-la-democratie'},
#                              {'author': 'Martine Orange',
#                               'id': '1030430 at https://www.mediapart.fr/',
#                               'image': 'https://static.mediapart.fr/etmagine/og/journal/files/2022/05/12/port-de-shanghai.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 11, 24, 32, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 11:24:32 +0200',
#                               'source': 'mediapart',
#                               'summary': 'La crise du Covid-19 puis la guerre '
#                                          'en Ukraine ont eu raison de '
#                                          'l’organisation industrielle mondiale '
#                                          'qui a prévalu pendant quatre '
#                                          'décennies. Le juste-à-temps, le zéro '
#                                          'stock ne sont plus de mise dans une '
#                                          'période marquée par les ruptures '
#                                          'd’approvisionnement et les pénuries. '
#                                          'Conscients de leur vulnérab[...]',
#                               'title': 'Le grand dérèglement de la machine '
# ...
#                                          'La France Insoumise ; à Jean-Luc '
#                                          'Mélenchon, d\'être un "autre Le '
#                                          'Pen", un "Chavez", un "bolivarien" ; '
#                                          'a[...]',
#                               'title': "Nupes : radiographie d'une panique "
#                                        'éditoriale',
#                               'url': 'https://www.arretsurimages.net/articles/nupes-radiographie-dune-panique-editoriale'},
#                              {'author': 'Jacques Trentesaux',
#                               'id': 'https://www.mediacites.fr/?p=238747',
#                               'image': 'https://www.mediacites.fr/wp-content/uploads/2022/05/2022-05-notes-frais-elus-lille-calais-valenciennes.jpg',
#                               'published': datetime.datetime(2022, 5, 13, 4, 30, 40, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 04:30:40 +0000',
#                               'source': 'mediacites',
#                               'summary': 'L’été dernier, Mediacités Lille '
#                                          'contactait douze collectivités des '
#                                          'Hauts-de-France pour tenter d’y voir '
#                                          'plus clair sur les notes de frais de '
#                                          'nos élus. L’étude des factures nous '
#                                          'a permis de déceler quelques '
#                                          'curiosités. Surtout, notre '
#                                          'initiative montre toutes les limites '
#                                          'd’une transparence qui est pou[...]',
#                               'title': 'Frais des élus\xa0:\xa0les premiers '
#                                        'résultats de notre opération '
#                                        'transparence',
#                               'url': 'https://www.mediacites.fr/enquete/lille/2022/05/13/frais-des-elus-les-premiers-resultats-de-notre-operation-transparence/'},
#                              {'author': 'Liam Brickhill',
#                               'id': 'https://afriquexxi.info/article4977.html',
#                               'image': '',
#                               'published': datetime.datetime(2022, 5, 13, 4, 0, tzinfo=tzlocal()),
#                               'published_key': 'updated',
#                               's_published': '2022-05-13T04:00:00Z',
#                               'source': 'afrique 21',
#                               'summary': 'Premier groupe de mbira punk du '
#                                          'Zimbabwe, Chikwata\xa0263 a '
#                                          'ressuscité les espoirs nés avec '
#                                          "l'indépendance. En suivant sa trace "
#                                          'du Book Café à Chimanimani, en '
#                                          'passant par le Mannenberg et les '
#                                          'quartiers miteux de Harare, le '
#                                          'journaliste Liam Brickhill - dont le '
#                                          'frère et le père ont joué un rôle '
#                                          'majeur da[...]',
#                               'title': "Quand l'espoir hurlait à plein volume "
#                                        'au Zimbabwe',
#                               'url': 'https://afriquexxi.info/article4977.html'},
#                              {'author': 'Kylian Marcos, Sarah Sermondadaz',
#                               'id': 'https://www.heidi.news/articles/la-suisse-atteint-son-jour-du-depassement-un-peu-plus-tard-qu-en-2021',
#                               'image': 'https://heidi-17455.kxcdn.com/photos/30a625fa-4c19-4f99-8492-e11b62a3cf6f/medium',
#                               'published': datetime.datetime(2022, 5, 13, 5, 55, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 05:55:00 +0200',
#                               'source': 'heidi news',
#                               'summary': 'Le jour du dépassement tombe ce '
#                                          'vendredi 13 mai pour la Suisse. '
#                                          'C’est à partir de ce jour que le '
#                                          'pays vit à crédit, compte tenu de sa '
#                                          'consommation de ressources, selon '
#                                          'cet indicateur établi par l’ONG '
#                                          'Global Carbon Footprint. Cela '
#                                          'signifie que la Confédération '
#                                          'utilise plus de quatre fois de '
#                                          'ressource[...]',
#                               'title': 'La Suisse atteint son jour du '
#                                        "dépassement, un peu plus tard qu'en "
#                                        '2021',
#                               'url': 'https://www.heidi.news/articles/la-suisse-atteint-son-jour-du-depassement-un-peu-plus-tard-qu-en-2021'},
#                              {'author': 'Aude Martin',
#                               'id': 'https://www.alternatives-economiques.fr/lallemagne-partie-responsable-de-desindustrialisation-francaise/00103322',
#                               'image': 'https://www.alternatives-economiques.fr/sites/default/files/public/styles/for_social_networks/public/field/image/allemagne-industrie-france.jpg?itok=Tqt8G6sY',
#                               'published': datetime.datetime(2022, 5, 13, 3, 50, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 03:50:00 +0200',
#                               'source': 'Alternatives Economiques',
#                               'summary': 'Sans coordination, une relance de la '
#                                          'demande en France pourrait nuire à '
#                                          'l’industrie hexagonale au profit de '
#                                          'l’Allemagne. Répétant le scénario du '
#                                          'début des années 2000.',
#                               'title': 'L’Allemagne est en partie responsable '
#                                        'de la désindustrialisation française',
#                               'url': 'https://www.alternatives-economiques.fr/lallemagne-partie-responsable-de-desindustrialisation-francaise/00103322'},
#                              {'author': 'Axelle Arquié',
#                               'id': 'https://www.alternatives-economiques.fr/inflation-banque-centrale-americaine-a-t-failli/00103337',
#                               'image': 'https://www.alternatives-economiques.fr/sites/default/files/public/styles/for_social_networks/public/field/image/fed-powell.jpg?itok=jgKfa5AG',
#                               'published': datetime.datetime(2022, 5, 13, 3, 45, tzinfo=tzoffset(None, 7200)),
#                               'published_key': 'published',
#                               's_published': 'Fri, 13 May 2022 03:45:00 +0200',
#                               'source': 'Alternatives Economiques',
#                               'summary': 'La Fed aurait tardé à relever ses '
#                                          'taux pour contenir l’inflation, '
#                                          'selon The Economist. Une critique '
#                                          'infondée, selon l’économiste Axelle '
#                                          'Arquié.',
#                               'title': 'Inflation\xa0: la banque centrale '
#                                        'américaine a-t-elle «\xa0failli\xa0'
#                                        '»\xa0?',
#                               'url': 'https://www.alternatives-economiques.fr/inflation-banque-centrale-americaine-a-t-failli/00103337'}],
#                  'feeds': [{'inpuut': 'https://www.off-investigation.fr/feed/',
#                             'keep_only': None,
#                             'name': 'off investigation'},
#                            {'inpuut': 'https://www.bastamag.net/spip.php?page=backend',
#                             'keep_only': None,
#                             'name': 'basta'},
#                            {'inpuut': 'https://lagedefaire-lejournal.fr/feed/',
#                             'keep_only': None,
#                             'name': "l'age de faire"},
#                            {'inpuut': 'https://reporterre.net/spip.php?page=backend-simple',
#                             'keep_only': None,
#                             'name': 'reporterre'},
#                            {'inpuut': 'https://www.youtube.com/channel/UCQgWpmt02UtJkyO32HGUASQ',
#                             'keep_only': None,
#                             'name': 'thinkerview'},
#                            {'inpuut': 'https://www.youtube.com/channel/UCVeMw72tepFl1Zt5fvf9QKQ',
#                             'keep_only': None,
#                             'name': 'osons causer'},
#                            {'inpuut': 'https://la-bas.org/spip.php?page=backend',
#                             'keep_only': None,
#                             'name': 'là bas'},
#                            {'inpuut': 'https://lvsl.fr/feed/',
#                             'keep_only': None,
#                             'name': 'le vent se lève'},
#                            {'inpuut': 'https://theconversation.com/fr/articles.atom',
#                             'keep_only': None,
#                             'name': 'the conversation fr'},
#                            {'inpuut': 'https://theconversation.com/ca-fr/home-page/articles.atom',
#                             'keep_only': None,
#                             'name': 'the conversation ca-fr'},
#                            {'inpuut': 'https://www.acrimed.org/spip.php?page=backend',
#                             'keep_only': None,
#                             'name': 'acrimed'},
#                            {'inpuut': 'https://www.institut-rousseau.fr/feed/',
#                             'keep_only': None,
#                             'name': 'institut rousseau'},
#                            {'inpuut': 'https://www.fakirpresse.info/spip.php?page=backend',
#                             'keep_only': None,
#                             'name': 'fakir'},
#                            {'inpuut': 'https://www.heidi.news/articles.rss',
#                             'keep_only': None,
#                             'name': 'heidi news'},
#                            {'inpuut': 'https://reflets.info/feeds/public',
#                             'keep_only': None,
#                             'name': 'reflets'},
#                            {'inpuut': 'https://www.lesnouvellesnews.fr/feed',
#                             'keep_only': None,
#                             'name': 'les nouvelles news'},
#                            {'inpuut': 'https://lesjours.fr/rss.xml',
#                             'keep_only': None,
#                             'name': 'les jours'},
#                            {'inpuut': 'https://rapportsdeforce.fr/feed',
#                             'keep_only': None,
#                             'name': 'rapports de force'},
#                            {'inpuut': 'https://radioparleur.net/feed/',
#                             'keep_only': None,
#                             'name': 'radio parleur'},
#                            {'inpuut': 'https://multinationales.org/spip.php?page=backend',
#                             'keep_only': None,
#                             'name': 'observatoire des multinationnales'},
#                            {'inpuut': 'https://www.alternatives-economiques.fr/rss.xml',
#                             'keep_only': None,
#                             'name': 'alternatives économiques'},
#                            {'inpuut': 'https://www.mediapart.fr/articles/feed',
#                             'keep_only': None,
#                             'name': 'mediapart'},
#                            {'inpuut': 'https://backend.streetpress.com/rss.xml',
#                             'keep_only': None,
#                             'name': 'street press'},
#                            {'inpuut': 'https://api.blast-info.fr/rss.xml',
#                             'keep_only': None,
#                             'name': 'blast'},
#                            {'inpuut': 'https://api.arretsurimages.net/api/public/rss/all-content',
#                             'keep_only': None,
#                             'name': 'arrêt sur image'},
#                            {'inpuut': 'https://www.mediacites.fr/feed/',
#                             'keep_only': None,
#                             'name': 'mediacites'},
#                            {'inpuut': 'https://www.bondyblog.fr/feed/',
#                             'keep_only': None,
#                             'name': 'bondy blog'},
#                            {'inpuut': 'https://www.monde-diplomatique.fr/rss/',
#                             'keep_only': None,
#                             'name': 'le monde diplo'},
#                            {'inpuut': 'https://afriquexxi.info/?page=backend&lang=fr',
#                             'keep_only': None,
#                             'name': 'afrique 21'},
#                            {'inpuut': 'https://guitinews.fr/feed/',
#                             'keep_only': None,
#                             'name': 'guiti news'},
#                            {'inpuut': 'https://www.youtube.com/channel/UC2ijB3_Fg2pIW1g6FeIiYKA',
#                             'keep_only': None,
#                             'name': 'backseat'},
#                            {'inpuut': 'https://mrmondialisation.org/feed/',
#                             'keep_only': None,
#                             'name': 'mr mondialisation'},
#                            {'inpuut': 'https://up-magazine.info/feed/',
#                             'keep_only': None,
#                             'name': 'up magazine'},
#                            {'inpuut': 'https://predictalab.medium.com/feed',
#                             'keep_only': None,
#                             'name': 'predicta lab'},
#                            {'inpuut': 'https://www.youtube.com/playlist?list=PLIVcDWpMT7KfTCsp2It3EVmMwG2C7CfPf',
#                             'keep_only': None,
#                             'name': 'Tom Nicholas'},
#                            {'inpuut': 'https://feeds.acast.com/public/shows/in-extenso',
#                             'keep_only': None,
#                             'name': 'In Extenso'},
#                            {'inpuut': 'https://www.youtube.com/channel/UCBiAHZy9Gghpt0JyDaz3SYw',
#                             'keep_only': None,
#                             'name': 'Xavier Tytelman - Ukraine'},
#                            {'inpuut': 'https://themarkup.org/feeds/rss.xml',
#                             'keep_only': None,
#                             'name': 'The Markup'},
#                            {'inpuut': 'https://www.youtube.com/channel/UC2ijB3_Fg2pIW1g6FeIiYKA',
#                             'keep_only': None,
#                             'name': 'Backseat'},
#                            {'inpuut': 'https://feeds.feedburner.com/pudding/feed',
#                             'keep_only': None,
#                             'name': 'The Pudding'},
#                            {'inpuut': 'https://poliverse.fr/index.xml',
#                             'keep_only': None,
#                             'name': 'poliverse'}],
#                  'import_feeds_from': None,
#                  'keep_only': None,
#                  'name': 'medias_indeps'}],
#  'description': 'médias indépendants',
#  'last_update': '13/05/22 21:41',
#  'max_age_minutes': 1440,
#  'name': 'medias_independants'}

# %%
url = "https://dev.to/magesh236/open-graph-protocol-analyer-4dk0"

from bs4 import BeautifulSoup
import requests


get_image_of_url(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 7>()
#       3 from bs4 import BeautifulSoup
#       4 import requests
# ----> 7 get_image_of_url(url)
#
# NameError: name 'get_image_of_url' is not defined
