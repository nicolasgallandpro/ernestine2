# %%
from rsc import *

p = Parsed_rsc("https://raw.githubusercontent.com/nicolasgallandpro/ernestine-data/main/medias_indeps.rsc")
raw = get_raw_posts(p)
formated_posts = prepare_curation_data_without_thumbnails(p, raw)
# Out:
# input https://www.off-investigation.fr/feed/
# input https://www.bastamag.net/spip.php?page=backend
# input https://lagedefaire-lejournal.fr/feed/
# input https://reporterre.net/spip.php?page=backend-simple
# input https://www.youtube.com/channel/UCQgWpmt02UtJkyO32HGUASQ
# input https://www.youtube.com/channel/UCVeMw72tepFl1Zt5fvf9QKQ
# input https://la-bas.org/spip.php?page=backend
# inputinput https://theconversation.com/fr/articles.atom
#  input https://theconversation.com/ca-fr/home-page/articles.atom
# https://lvsl.fr/feed/input https://www.acrimed.org/spip.php?page=backend
#
# input https://www.institut-rousseau.fr/feed/
# input https://www.fakirpresse.info/spip.php?page=backend
# input https://www.heidi.news/articles.rss
# inputinput  https://www.lesnouvellesnews.fr/feed
# https://reflets.info/feeds/public
# input https://lesjours.fr/rss.xml
# input https://rapportsdeforce.fr/feed
# input https://radioparleur.net/feed/
# input https://multinationales.org/spip.php?page=backend
# ...

# %%
from pprint import pprint

pprint(formated_posts.to_json())
# Out:
# {'categories': [{'entries': [{'author': 'joweisz',
#                               'id': '14920 at https://backend.streetpress.com',
#                               'image': None,
#                               'published': datetime.datetime(2022, 4, 6, 14, 30, 28, tzinfo=tzlocal()),
#                               'published_key': 'published',
#                               's_published': 'Wed, 06 Apr 2022 14:30:28 +0000',
#                               'source': 'street press',
#                               'summary': 'Le journaliste Philippe Nassif vient '
#                                          'de nous quitter. Né en 1971 à '
#                                          'Beyrouth, il aura marqué le monde du '
#                                          'journalisme et des idées de ces '
#                                          'vingt dernières années. Pour '
#                                          'StreetPress, il était un maître à '
# ...
